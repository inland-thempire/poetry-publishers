# %%
import pandas as pd

# %%
df = pd.read_csv('publishers_joined_dataset.csv',encoding='latin-1')

# %%
df.head()
# Out:
#           Publisher   Latitude   Longitude  \
# 0  #Ranger Magazine  38.881621  -77.090981
# 1       11:11 Press  44.429409  -93.201883
# 2        1913 Press  33.143372 -117.166145
# 3    42 Miles Press  41.676355  -86.251990
# 4   9th House Press  49.603236 -119.683418
#
#                       Formatted address                          Website  \
# 0  Arlington County, Arlington, VA, USA  https://www.rangermagazine.net/
# 1                       Dundas, MN, USA           https://1111press.com/
# 2                   San Marcos, CA, USA         http://www.1913press.org
# 3                   South Bend, IN, USA        https://42milespress.com/
# 4            Summerland, BC V0H, Canada   https://www.9thhousepress.com/
#
#   Type of Publisher                                   Genres Published  \
# 0   Magazine, Press            Poetry, Audio, Experimental, Visual Art
# 1             Press  Fiction, Poetry, Cross Genre Hybrid, Environme...
# ...

# %%
df.Distributor.value_counts()
# Out:
# Distributor
# Asterism Books and publisher website                13
# Publisher website                                   12
# Ingram                                              11
# Asterism Books                                      10
# Other                                                7
# Itasca Books and publisher website                   6
# Amazon                                               6
# Amazon and other                                     5
# IngramSpark                                          4
# Ingram and publisher website                         4
# Asterism Books and other                             3
# Self-distribution                                    2
# Asterism Books and Ingram                            1
# Itasca Books                                         1
# Independent Publishers Group                         1
# Distributed Art Publishers and publisher website     1
# Name: count, dtype: int64

# %%
df.Distributor.value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>
